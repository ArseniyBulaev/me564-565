# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %% [markdown]
# Exercise 3.1

# %%
t0 = 0
tbound = 10
first_step = 0.01
max_step = first_step
t = np.arange(t0, tbound, first_step)
def  dxdt(t,X):
              return A @ X

# %% [markdown]
# (a)

# %%
def analytic_sol_a(t):
    return 0.5 * np.exp(-2 * t)

A = [
    [0, 1],
    [-6, -5]
]

boundary_conditions = [0.5, -1]

# %%
linear_ode_solution_0 = sp.integrate.solve_ivp(dxdt, (t0, tbound), boundary_conditions, t_eval=t)
x = linear_ode_solution_0.y

# %%
plt.figure()
plt.plot(t, x[0, :], 'r')
plt.plot(t, analytic_sol_a(t), 'g')
plt.xlabel('Time [s]')
plt.ylabel('Solution x')
plt.legend(['numeric', 'analytic'])
plt.grid(True)
plt.show()
